# %% [markdown]
# <a href="https://colab.research.google.com/github/AlmaBasic/Predicting/blob/main/Untitled01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
diseases = pd.read_csv('disease.csv')
#diseases
#diseases.shape
#diseases.describe()
#diseases.info()
#diseases.describe(include=['O'])
diseases.describe(include='all')
# Out:
#        disease_id                             name  \
# count        2834                             2827
# unique       2834                             2827
# top       C531616  Amyotrophic lateral sclerosis 1
# freq            1                                1
#
#                                                     alias
# count                                                2418
# unique                                               2418
# top     ALS1#AMYOTROPHIC LATERAL SCLEROSIS 1, AUTOSOMA...
# freq                                                    1
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('disease_id').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('alias').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['name'].value_counts()
#     for x_label, grp in _df_3.groupby('disease_id')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('disease_id')
# _ = plt.ylabel('name')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['alias'].value_counts()
#     for x_label, grp in _df_4.groupby('name')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('name')
# _ = plt.ylabel('alias')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_0.groupby('disease_id').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
association = pd.read_csv('drug-disease association.csv')
#association
#association.shape
association.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49217 entries, 0 to 49216
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   drug_id       49217 non-null  object
#  1   drug_name     49142 non-null  object
#  2   disease_id    49217 non-null  object
#  3   disease_name  49200 non-null  object
# dtypes: object(4)
# memory usage: 1.5+ MB

# %%
drug = pd.read_csv('drug.csv')
#drug
#drug.shape
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1323 entries, 0 to 1322
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   drug_id      1323 non-null   object
#  1   name         1321 non-null   object
#  2   drugbank_id  1319 non-null   object
#  3   pubchem_cid  1305 non-null   float64
#  4   alias        1224 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 51.8+ KB
